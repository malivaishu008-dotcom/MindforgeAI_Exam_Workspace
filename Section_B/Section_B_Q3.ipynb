# %% [markdown]
# Q3. Variables, Memory and Identity
# Ans:-
#
# 1.a, b, and c all point to the same integer object (25), so their identity is the same (a is b is c → True).
#
# 2.names and same_names point to the same list object. After same_names.append("Neha"), both variables contain ["Asha", "Riya", "Neha"], and names is same_names → True
