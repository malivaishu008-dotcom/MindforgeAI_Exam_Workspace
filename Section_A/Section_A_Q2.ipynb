# %% [markdown]
# Q2. Data Analytics Pipeline Algorithm
# ans:-
# 1.Start.
#
# 2.Read the student dataset.
#
# 3.If the dataset is empty, display "No data found" and stop.
#
# 4.For each student, check for missing values.
#
# 5.Calculate the readiness score.
#
# 6.Classify the student as Support, Developing, Strong, or Excellent based on the score.
#
# 7.Calculate department-wise average scores.
#
# 8.Find the top-performing student.
#
# 9.Display students who need support and the final report.
#
# 10.End.
