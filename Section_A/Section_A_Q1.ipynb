# %% [markdown]
# Q1. Workspace Architecture Map
# Ans:-
#
# 1.VS Code: Write and organize project files.
#
# 2.Jupyter Notebook: Run Python code and view outputs.
#
# 3.Google Colab: Run notebooks online if needed.
#
# 4.GitHub: Store and manage project code.
#
# 5.Google Drive: Keep submission files in one place.
#
# 6.Student Portal: Submit all required links.
